# %% [markdown]
# # This is a heading
# ## This is a less major heading
#
# Here is some text
# Here is some **bold** rwzt

# %%
print("Hello World")

my_var = 2
print(my_var * 2)
# Out:
# Hello World
# 4
